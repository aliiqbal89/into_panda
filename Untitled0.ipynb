# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
number_series = pd.Series([2,3,5,6,8])
print(number_series)
# Out:
# 0    2
# 1    3
# 2    5
# 3    6
# 4    8
# dtype: int64

# %%
number_series = pd.Series([2,3,5,6,8], index=['a','b','d','e','e'], name= 'Number')

# %%
print(number_series[1])
print(number_series['d'])
# Out:
# 3
# 5
# <ipython-input-8-0a3bd978db30>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(number_series[1])

# %%
list_of_lists = [['Amar', 10], ['Akbar',15], ['anthony',14]]
df = pd.DataFrame(list_of_lists,columns=['Name', 'Age'])
df
# Out:
#       Name  Age
# 0     Amar   10
# 1    Akbar   15
# 2  anthony   14

# %%
employee_dict = {'Employee Name': ['ali', 'rana', 'king'], 'income': [10000,20000,30000]}
employee_dict_df= pd.DataFrame(employee_dict)
employee_dict_df
# Out:
#   Employee Name  income
# 0           ali   10000
# 1          rana   20000
# 2          king   30000

# %%
series_dict = {'First Series' : pd.Series([10,20,30,40,50]),
              'second Series' : pd.Series([10,20,30,40,50])}
df = pd.DataFrame(series_dict)
df
# Out:
#    First Series  second Series
# 0            10             10
# 1            20             20
# 2            30             30
# 3            40             40
# 4            50             50

# %%
list_of_dict = [{'a':1,'b':2,'c':3},{'a':10,'b':20,'c':30}]
df = pd.DataFrame(list_of_dict)
df
# Out:
#     a   b   c
# 0   1   2   3
# 1  10  20  30

# %%
our_array = np.random.randn(100,5)
df = pd.DataFrame(our_array,columns=['A','b','c','d','e'])
df
# Out:
#            A         b         c         d         e
# 0  -1.173481  1.062760  0.408830 -0.652342  0.887678
# 1  -0.084211 -0.631684  0.017108 -0.849225  0.130765
# 2  -0.912240 -1.100413  0.497783 -1.745345 -0.151756
# 3  -1.355057 -0.144082  0.438827 -0.580696 -0.380738
# 4   1.660358  0.614223  0.297569  1.134445  0.049405
# ..       ...       ...       ...       ...       ...
# 95 -1.093213 -0.455517 -0.455204  0.315385  0.206026
# 96  0.134360 -0.193993 -0.883328  0.866416  0.316151
# 97  0.324344  2.070274  0.223640 -1.877761  2.013938
# 98 -0.389375 -1.480458 -0.247600 -0.690952 -0.032198
# 99 -1.470777  1.307235  0.660094  1.387555  0.289009
#
# [100 rows x 5 columns]

# %%
df.head()
# Out:
#           A         b         c         d         e
# 0 -1.173481  1.062760  0.408830 -0.652342  0.887678
# 1 -0.084211 -0.631684  0.017108 -0.849225  0.130765
# 2 -0.912240 -1.100413  0.497783 -1.745345 -0.151756
# 3 -1.355057 -0.144082  0.438827 -0.580696 -0.380738
# 4  1.660358  0.614223  0.297569  1.134445  0.049405

# %%
df.head(5)
# Out:
#           A         b         c         d         e
# 0 -1.173481  1.062760  0.408830 -0.652342  0.887678
# 1 -0.084211 -0.631684  0.017108 -0.849225  0.130765
# 2 -0.912240 -1.100413  0.497783 -1.745345 -0.151756
# 3 -1.355057 -0.144082  0.438827 -0.580696 -0.380738
# 4  1.660358  0.614223  0.297569  1.134445  0.049405

# %%
df.tail()
# Out:
#            A         b         c         d         e
# 95 -1.093213 -0.455517 -0.455204  0.315385  0.206026
# 96  0.134360 -0.193993 -0.883328  0.866416  0.316151
# 97  0.324344  2.070274  0.223640 -1.877761  2.013938
# 98 -0.389375 -1.480458 -0.247600 -0.690952 -0.032198
# 99 -1.470777  1.307235  0.660094  1.387555  0.289009

# %%
df.tail(10)
# Out:
#            A         b         c         d         e
# 90 -0.995624  0.185979 -0.625430  0.725034 -1.129145
# 91  0.994143 -0.288797  0.739647 -0.288480 -1.736424
# 92  0.014230 -1.092988 -0.954415  0.234176 -0.206324
# 93  0.358501 -0.888355 -0.636652  0.998909  0.781043
# 94 -0.953537  0.259077 -1.285577  1.007492  1.527654
# 95 -1.093213 -0.455517 -0.455204  0.315385  0.206026
# 96  0.134360 -0.193993 -0.883328  0.866416  0.316151
# 97  0.324344  2.070274  0.223640 -1.877761  2.013938
# 98 -0.389375 -1.480458 -0.247600 -0.690952 -0.032198
# 99 -1.470777  1.307235  0.660094  1.387555  0.289009

# %%
list(df.columns)
# Out:
# ['A', 'b', 'c', 'd', 'e']
